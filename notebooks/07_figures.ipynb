# %% [markdown]
# # 07 — Publication figures and tables
#
# **Phase 7.** Runs locally on the downloaded CSVs (no GPU needed).
#
# ## What this notebook does
# 1. Loads all `results/*.csv` files.
# 2. Produces publication-grade figures with a colorblind-friendly palette:
#    - `figures/main_results.png` — SSIM/PSNR/VIF bar chart per method
#    - `figures/convergence_curves.png` — per-round metric across methods
#    - `figures/coverage.png` — target vs empirical coverage
#    - `figures/qualitative_grid.png` — 4-case (MRI, PET, fused, heatmap)
#    - `figures/comm_cost.png` — bytes/round bar chart
#    - `figures/attack_reconstructions.png` — DLG outputs per protection level
# 3. Emits LaTeX-ready tables to `paper/tables/`.
#
# ## Status
# Stub. Filled in Phase 7.
